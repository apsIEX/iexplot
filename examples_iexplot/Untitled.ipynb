# %%
# %config Completer.use_jedi = False  
from iexcode import *
from iexcode.xrays_imports import *
from iexcode.instruments.IEX_VPU import *

# %%
ID._coef('MEG',0,300,100)
# Out:
# Traceback (most recent call last):
#
#   File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     ID._coef('MEG',0,300,100)
#
#   File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IEX_VPU.py:700 in _coef
#     ID_function=read_dict(IDcal_fpath)
#
#   File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/utilities.py:142 in read_dict
#     mydict=ast.literal_eval(lastline)
#
#   File ~/.conda/envs/bluesky_2024_1/lib/python3.11/ast.py:64 in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File ~/.conda/envs/bluesky_2024_1/lib/python3.11/ast.py:50 in parse
#     return compile(source, filename, mode, flags,
#
#   File <unknown>:1
# ...

# %%
cal = IDCal_dict()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cal = IDCal_dict()
#
# File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IEX_VPU.py:801, in IDCal_dict.__init__(self, **kwargs)
#     799 self.new_comment = None
#     800 self.new_entry = None
# --> 801 self.read(**kwargs)
#
# File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IEX_VPU.py:867, in IDCal_dict.read(self, **kwargs)
#     864     index2 += 1
#     866 index = kwargs['index']
# --> 867 comment, entry = entries[index]
#     869 if kwargs['debug']:
#     870     print("\ Selected Entry comment", comment)
#
# IndexError: list index out of range

# %%
IDcal_path
# Out:
# '/home/beams/29IDUSER/Documents/User_Macros/Macros_29id/IEX_Dictionaries/'

# %%
cal.read()

# %%
cal.last_comment
# Out:
# '20250603:'

# %%
cal.update_entry('MEG',0,3800,[-13.182313885263655, 1.0257452797931057])

# %%
cal.update_entry('MEG',1,3800,[-13.182313885263655, 1.0257452797931057])

# %%
cal.get_coefs(cal.last_entry,'MEG',0,500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cal.get_coefs(cal.last_entry,'MEG',0,500)
#
# File ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IEX_VPU.py:898, in IDCal_dict.get_coefs(self, entry, grt, IDmode, energy_eV)
#     896 if grt in entry.keys():
#     897     if IDmode in entry[grt].keys():
# --> 898         breakpoint_list = list(entry[grt][IDmode].keys())
#     899         sorted_breakpoints = np.sort(np.array(breakpoint_list))
#     900         #find breakpoint to use
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
cal.last_comment
# Out:
# '20250603:'

# %%
idcal = IDCal_dict()

# %%
IDCal_dict?
# Out:
# Init signature: IDCal_dict()
# Docstring:      <no docstring>
# Init docstring:
# written by Ezekiel Lopez 20250627
# Used to read and write ID calibration to a text file
# default filepath and filename are the global variables default_filename, default_path
#
# usage:
# reading in a dictionary and getting coefs
#     cal = IDCal_dict()
#     cal.read()
#     cal.get_coefs
# updating the cal.new_entry
#     cal.update_entry
# writing to file the cal.new_entry
#     cal.update_entry
# File:           ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IDCal_dict.py
# Type:           type
# Subclasses:

# %%
print(idcal.last_entry)
# Out:
# None

# %%
idcal.read()

# %%
idcal.last_entry
# Out:
# {'MEG': {0: {3800: [4.123652309040438,
#     0.9892954083383053,
#     -5.976828110159691e-06,
#     -2.5962419521163995e-10]},
#   1: {3800: [5.2378656602703275,
#     0.9962855423158294,
#     -3.066797857348431e-05,
#     9.019205699466247e-09]},
#   2: {3800: [6.915661386670841,
#     0.9767674761343349,
#     9.81290115935925e-06,
#     -2.8084146833206264e-09]},
#   3: {3800: [5.218266574382144,
#     0.9908358876775277,
#     1.6061162974763392e-05,
#     -2.023561844126996e-09]}}}

# %%
idcal.get_coefs??
# Out:
# Signature: idcal.get_coefs(entry, grt, IDmode, energy_eV)
# Docstring:
#  parse entry only works for dictionaries of the type:
# {"MEG": {0: {bkpt1: [polynomials], bkpt2: [polynomials]}}}
#
# Parses a calibration dictionary and returns the coefficients corresponding
# to the first breakpoint greater than the specified energy value.
#
# Args:
#     entry (dict): Calibration dictionary.
#     grating (str): e.g., "MEG"
#     ID_mode (int): e.g., 0
#     energy_eV (float): photon energy in eV
#
# Returns:
#     list: Coefficient list for the nearest breakpoint >= energy_eV
#     bkpt_max = 3800
# File:      ~/.conda/envs/bluesky_2024_1/lib/python3.11/site-packages/iexcode/instruments/IDCal_dict.py
# Type:      method

# %%
fname='Dict_IDCal.txt' 
fname.split(".")
# Out:
# ['Dict_IDCal', 'txt']

# %%
fname
